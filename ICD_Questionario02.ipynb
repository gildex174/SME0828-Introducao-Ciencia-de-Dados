# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

import seaborn as sns

# %% [markdown]
# Link do dataset: https://www.kaggle.com/datasets/kumarajarshi/life-expectancy-who

# %%
data = pd.read_csv('data/Life Expectancy Data.csv')

# %%
data.head(3)
# Out:
#        Country  Year      Status  Life expectancy   Adult Mortality  \
# 0  Afghanistan  2015  Developing              65.0            263.0
# 1  Afghanistan  2014  Developing              59.9            271.0
# 2  Afghanistan  2013  Developing              59.9            268.0
#
#    infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   ...  \
# 0             62     0.01               71.279624         65.0      1154  ...
# 1             64     0.01               73.523582         62.0       492  ...
# 2             66     0.01               73.219243         64.0       430  ...
#
#    Polio  Total expenditure  Diphtheria    HIV/AIDS         GDP  Population  \
# 0    6.0               8.16         65.0        0.1  584.259210  33736494.0
# 1   58.0               8.18         62.0        0.1  612.696514    327582.0
# 2   62.0               8.13         64.0        0.1  631.744976  31731688.0
#
#     thinness  1-19 years   thinness 5-9 years  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2938 entries, 0 to 2937
# Data columns (total 22 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Country                          2938 non-null   object
#  1   Year                             2938 non-null   int64
#  2   Status                           2938 non-null   object
#  3   Life expectancy                  2928 non-null   float64
#  4   Adult Mortality                  2928 non-null   float64
#  5   infant deaths                    2938 non-null   int64
#  6   Alcohol                          2744 non-null   float64
#  7   percentage expenditure           2938 non-null   float64
#  8   Hepatitis B                      2385 non-null   float64
#  9   Measles                          2938 non-null   int64
#  10   BMI                             2904 non-null   float64
#  11  under-five deaths                2938 non-null   int64
# ...

# %%
year = [2014]
filtered_df = data[data['Year'].isin(year)]

# %%
filtered_df.head(3)
# Out:
#         Country  Year      Status  Life expectancy   Adult Mortality  \
# 1   Afghanistan  2014  Developing              59.9            271.0
# 17      Albania  2014  Developing              77.5              8.0
# 33      Algeria  2014  Developing              75.4             11.0
#
#     infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   \
# 1              64     0.01               73.523582         62.0       492
# 17              0     4.51              428.749067         98.0         0
# 33             21     0.01               54.237318         95.0         0
#
#     ...  Polio  Total expenditure  Diphtheria    HIV/AIDS          GDP  \
# 1   ...   58.0               8.18         62.0        0.1   612.696514
# 17  ...   98.0               5.88         98.0        0.1  4575.763787
# 33  ...   95.0               7.21         95.0        0.1   547.851700
#
#     Population   thinness  1-19 years   thinness 5-9 years  \
# ...

# %%
filtered_df.columns
# Out:
# Index(['Country', 'Year', 'Status', 'Life expectancy ', 'Adult Mortality',
#        'infant deaths', 'Alcohol', 'percentage expenditure', 'Hepatitis B',
#        'Measles ', ' BMI ', 'under-five deaths ', 'Polio', 'Total expenditure',
#        'Diphtheria ', ' HIV/AIDS', 'GDP', 'Population',
#        ' thinness  1-19 years', ' thinness 5-9 years',
#        'Income composition of resources', 'Schooling'],
#       dtype='object')

# %%
print(filtered_df['Life expectancy '].max())
print(filtered_df['Life expectancy '].min())
# Out:
# 89.0
# 48.1

# %%
filtered_df[filtered_df['Life expectancy '] == filtered_df['Life expectancy '].max()]
# Out:
#        Country  Year      Status  Life expectancy   Adult Mortality  \
# 241    Belgium  2014   Developed              89.0             76.0
# 915    Finland  2014  Developing              89.0             78.0
# 995    Germany  2014   Developed              89.0             69.0
# 2056  Portugal  2014   Developed              89.0             78.0
#
#       infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   \
# 241               0    12.60             7163.348923         98.0        70
# 915               0     8.80             6164.455402          NaN         0
# 995               2    11.03              941.756291         88.0       443
# 2056              0     9.88              271.254553         98.0         0
#
#       ...  Polio  Total expenditure  Diphtheria    HIV/AIDS          GDP  \
# 241   ...   99.0               1.59         99.0        0.1  47439.39684
# 915   ...   98.0               9.68         98.0        0.1  49914.61864
# ...

# %%
filtered_df[filtered_df['Life expectancy '] == filtered_df['Life expectancy '].min()]
# Out:
#            Country  Year      Status  Life expectancy   Adult Mortality  \
# 2298  Sierra Leone  2014  Developing              48.1            463.0
#
#       infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   \
# 2298             23     0.01                1.443286         83.0      1006
#
#       ...  Polio  Total expenditure  Diphtheria    HIV/AIDS        GDP  \
# 2298  ...   83.0               11.9         83.0        0.6  78.439476
#
#       Population   thinness  1-19 years   thinness 5-9 years  \
# 2298    779162.0                    7.5                  7.4
#
#       Income composition of resources  Schooling
# 2298                            0.426        9.5
#
# [1 rows x 22 columns]

# %% [markdown]
# ## Q. 01

# %%
countries_list = ['Ireland', 'Finland', 'Netherlands', 'Zambia', 'Angola']

filtered_df = data[data['Country'].isin(countries_list)]

# %%
filtered_df['Country'].unique()
# Out:
# array(['Angola', 'Finland', 'Ireland', 'Netherlands', 'Zambia'],
#       dtype=object)

# %%
filtered_df
# Out:
#      Country  Year      Status  Life expectancy   Adult Mortality  \
# 48    Angola  2015  Developing              52.4            335.0
# 49    Angola  2014  Developing              51.7            348.0
# 50    Angola  2013  Developing              51.1            355.0
# 51    Angola  2012  Developing              56.0            358.0
# 52    Angola  2011  Developing              51.0            361.0
# ...      ...   ...         ...               ...              ...
# 2917  Zambia  2004  Developing              47.9            578.0
# 2918  Zambia  2003  Developing              46.4             64.0
# 2919  Zambia  2002  Developing              45.5             69.0
# 2920  Zambia  2001  Developing              44.6            611.0
# 2921  Zambia  2000  Developing              43.8            614.0
#
#       infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   \
# 48               66      NaN                0.000000         64.0       118
# ...

# %%
filtered_df = filtered_df[filtered_df['Year'].isin([2014])]

# %%
filtered_df
# Out:
#           Country  Year      Status  Life expectancy   Adult Mortality  \
# 49         Angola  2014  Developing              51.7            348.0
# 915       Finland  2014  Developing              89.0             78.0
# 1251      Ireland  2014   Developed              81.2             66.0
# 1830  Netherlands  2014   Developed              81.7             58.0
# 2907       Zambia  2014  Developing              61.1            314.0
#
#       infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   \
# 49               67     8.33               23.965612         64.0     11699
# 915               0     8.80             6164.455402          NaN         0
# 1251              0    10.75              746.367045         95.0        33
# 1830              1     0.01             1491.703605         92.0       140
# 2907             28     0.01              196.667577         86.0         9
#
#       ...  Polio  Total expenditure  Diphtheria    HIV/AIDS          GDP  \
# ...

# %% [markdown]
# ## Q. 02

# %%
countries_list = ['Ireland', 'Netherlands', 'Zambia', 'Angola']

filtered_df = data[data['Country'].isin(countries_list)]

# %%
filtered_df.columns
# Out:
# Index(['Country', 'Year', 'Status', 'Life expectancy ', 'Adult Mortality',
#        'infant deaths', 'Alcohol', 'percentage expenditure', 'Hepatitis B',
#        'Measles ', ' BMI ', 'under-five deaths ', 'Polio', 'Total expenditure',
#        'Diphtheria ', ' HIV/AIDS', 'GDP', 'Population',
#        ' thinness  1-19 years', ' thinness 5-9 years',
#        'Income composition of resources', 'Schooling'],
#       dtype='object')

# %%
sns.boxplot(data=filtered_df, x='Schooling')
# Out:
# <Axes: xlabel='Schooling'>

# %%
filtered_df[filtered_df['Country'] == 'Ireland']['Schooling'].median()
# Out:
# 17.75

# %%
max_median = 0
name_country = ''
for country in countries_list:
    median = filtered_df[filtered_df['Country'] == country]['Schooling'].median()

    if(median > max_median):
        max_median = median
        name_country = country
print(name_country)
# Out:
# Ireland

# %% [markdown]
# ## Q. 03

# %%
url = 'https://gist.github.com/aishwarya8615/89d9f36fc014dea62487f7347864d16a'
df_html = pd.read_html(url)[0]

# %%
status_counts = df_html['Status'].value_counts()
plt.pie(status_counts, labels=status_counts.index, autopct='%1.1f%%', startangle=140)
plt.axis('equal')
plt.title('Status')
plt.show()

# %% [markdown]
# Divergência possívelmente por eu não estar usando esatmente o mesmo dataset.

# %% [markdown]
# ## Q. 04

# %% [markdown]
# Histograma. media e variancia

# %%
url = 'https://gist.github.com/aishwarya8615/89d9f36fc014dea62487f7347864d16a'
df_html = pd.read_html(url)[0]

# %%
df_html.columns
# Out:
# Index(['Unnamed: 0', 'Country', 'Continent', 'Year', 'Status',
#        'Life_expectancy', 'Adult_Mortality', 'infant_deaths', 'Alcohol',
#        'percentage_expenditure', 'Hepatitis_B', 'Measles', 'BMI',
#        'under_five_deaths', 'Polio', 'Total_expenditure', 'Diphtheria',
#        'HIV/AIDS', 'GDP', 'Population', 'thinness 1-19 years',
#        'thinness 5-9 years', 'Income_composition_of_resources', 'Schooling'],
#       dtype='object')

# %%
df_html.head(5)
# Out:
#    Unnamed: 0      Country Continent  Year      Status  Life_expectancy  \
# 0         NaN  Afghanistan      Asia  2015  Developing             65.0
# 1         NaN  Afghanistan      Asia  2014  Developing             59.9
# 2         NaN  Afghanistan      Asia  2013  Developing             59.9
# 3         NaN  Afghanistan      Asia  2012  Developing             59.5
# 4         NaN  Afghanistan      Asia  2011  Developing             59.2
#
#    Adult_Mortality  infant_deaths  Alcohol  percentage_expenditure  ...  \
# 0              263             62     0.01               71.279624  ...
# 1              271             64     0.01               73.523582  ...
# 2              268             66     0.01               73.219243  ...
# 3              272             69     0.01               78.184215  ...
# 4              275             71     0.01                7.097109  ...
#
#    Polio  Total_expenditure  Diphtheria  HIV/AIDS         GDP  Population  \
# ...

# %%
plt.hist(df_html['Life_expectancy'], bins=20, edgecolor='black')
plt.xlabel('Population')
plt.ylabel('Frequency')
plt.title('Life expectancy Hist')
plt.show()

# %%
print(df_html['Life_expectancy'].mean())
print(df_html['Life_expectancy'].var())
# Out:
# 69.46456724908573
# 92.91774400980518

# %% [markdown]
# ## Q.05

# %%
from bs4 import BeautifulSoup
import requests

url = 'https://www.worldometers.info/world-population/population-by-country/'

response = requests.get(url)
soup = BeautifulSoup(response.content, 'html.parser')


table = soup.find('table', {'id':'example2'})

df = pd.read_html(str(table))[0]

df.head(5)
# Out:
#    # Country (or dependency)  Population  (2023) Yearly  Change  Net  Change  \
# 0  1                   India          1428627663         0.81 %     11454490
# 1  2                   China          1425671352        -0.02 %      -215985
# 2  3           United States           339996563         0.50 %      1706706
# 3  4               Indonesia           277534122         0.74 %      2032783
# 4  5                Pakistan           240485658         1.98 %      4660796
#
#    Density  (P/Km²)  Land Area  (Km²)  Migrants  (net)  Fert.  Rate  \
# 0               481           2973190          -486136          2.0
# 1               152           9388211          -310220          1.2
# 2                37           9147420           999700          1.7
# 3               153           1811570           -49997          2.1
# 4               312            770880          -165988          3.3
#
#    Med.  Age Urban  Pop % World  Share
# 0       28.0         36 %      17.76 %
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 234 entries, 0 to 233
# Data columns (total 12 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   #                        234 non-null    int64
#  1   Country (or dependency)  234 non-null    object
#  2   Population  (2023)       234 non-null    int64
#  3   Yearly  Change           234 non-null    object
#  4   Net  Change              234 non-null    int64
#  5   Density  (P/Km²)         234 non-null    int64
#  6   Land Area  (Km²)         234 non-null    int64
#  7   Migrants  (net)          234 non-null    int64
#  8   Fert.  Rate              233 non-null    float64
#  9   Med.  Age                233 non-null    float64
#  10  Urban  Pop %             234 non-null    object
#  11  World  Share             234 non-null    object
# dtypes: float64(2), int64(6), object(4)
# memory usage: 22.1+ KB

# %%
df.head(2)
# Out:
#    # Country (or dependency)  Population  (2023) Yearly  Change  Net  Change  \
# 0  1                   India          1428627663         0.81 %     11454490
# 1  2                   China          1425671352        -0.02 %      -215985
#
#    Density  (P/Km²)  Land Area  (Km²)  Migrants  (net)  Fert.  Rate  \
# 0               481           2973190          -486136          2.0
# 1               152           9388211          -310220          1.2
#
#    Med.  Age Urban  Pop % World  Share
# 0       28.0         36 %      17.76 %
# 1       39.0         65 %      17.72 %

# %%
list_drop = [df.columns[0], df.columns[1]]
df.drop(list_drop, inplace=True, axis=1)

# %%
df.head(2)
# Out:
#    Population  (2023) Yearly  Change  Net  Change  Density  (P/Km²)  \
# 0          1428627663         0.81 %     11454490               481
# 1          1425671352        -0.02 %      -215985               152
#
#    Land Area  (Km²)  Migrants  (net)  Fert.  Rate  Med.  Age Urban  Pop %  \
# 0           2973190          -486136          2.0       28.0         36 %
# 1           9388211          -310220          1.2       39.0         65 %
#
#   World  Share
# 0      17.76 %
# 1      17.72 %

# %%
df.columns
# Out:
# Index(['Population  (2023)', 'Yearly  Change', 'Net  Change',
#        'Density  (P/Km²)', 'Land Area  (Km²)', 'Migrants  (net)',
#        'Fert.  Rate', 'Med.  Age', 'Urban  Pop %', 'World  Share'],
#       dtype='object')

# %%
df['Urban  Pop %'].replace('%', '', inplace=True)

# %%
df
# Out:
#      Population  (2023) Yearly  Change  Net  Change  Density  (P/Km²)  \
# 0            1428627663         0.81 %     11454490               481
# 1            1425671352        -0.02 %      -215985               152
# 2             339996563         0.50 %      1706706                37
# 3             277534122         0.74 %      2032783               153
# 4             240485658         1.98 %      4660796               312
# ..                  ...            ...          ...               ...
# 229                4386        -0.09 %           -4                44
# 230                3791         0.29 %           11                 0
# 231                1935         0.05 %            1                 7
# 232                1893         1.18 %           22               189
# 233                 518         1.57 %            8              1295
#
#      Land Area  (Km²)  Migrants  (net)  Fert.  Rate  Med.  Age Urban  Pop %  \
# ...

# %%
corr = df.corr()
mask = np.triu(np.ones_like(corr))
dataplot = sns.heatmap(corr, cmap="YlGnBu", annot=True, mask=mask)

plt.show()
# Out:
# /tmp/ipykernel_5633/2942606122.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr = df.corr()
